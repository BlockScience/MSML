# %%
import os

os.chdir("..")
from src.math_spec_mapping import find_open_issues, create_priority_label_matrix, create_milestone_label_matrix

df, open_issues = find_open_issues()
table1 = create_priority_label_matrix(df, exclude_milestones = ["V0.3.17",
                                                               "V0.3.18",
                                                               "V0.3.19",
                                                               "V0.3.20",
                                                               "V0.3.21",
                                                               "V0.4.0"])

table2 = create_milestone_label_matrix(df, exclude_milestones = ["V0.3.17"])
# Out:
# /Users/seanmcowen/Dropbox/BlockScience/MSML/src/math_spec_mapping/Convenience/github.py:53: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Labels"]
# /Users/seanmcowen/Dropbox/BlockScience/MSML/src/math_spec_mapping/Convenience/github.py:80: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   table = table.applymap(
# /Users/seanmcowen/Dropbox/BlockScience/MSML/src/math_spec_mapping/Convenience/github.py:103: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   table = table.applymap(

# %%
print(table2.to_markdown())
# Out:
# |                 | V0.3.18                                                                                                                        | V0.3.19                                                                                                                                               | V0.3.20                                                                                                             | V0.3.21                                                                                                                                                                      | V0.4.0                                                                                                              |
# ...

# %%
print(table1.to_markdown())
# Out:
# |                 | High Priority                                                                                                                                                                  | Medium Priority                                                                                                                                                                        | Low Priority                                                                                                                                                              |
# ...

# %%
from IPython.display import Markdown, display_markdown
display_markdown(Markdown(table1.to_markdown()))
# Out:
# |                 | High Priority                                                                                                                                                                  | Medium Priority                                                                                                                                                                        | Low Priority                                                                                                                                                              |
# ...

# %%
display_markdown(Markdown(table2.to_markdown()))
# Out:
# |                 | V0.3.18                                                                                                                        | V0.3.19                                                                                                                                               | V0.3.20                                                                                                             | V0.3.21                                                                                                                                                                      | V0.4.0                                                                                                              |
# ...
