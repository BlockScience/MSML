# %%
import os

os.chdir("..")
from src.math_spec_mapping import find_open_issues, create_priority_label_matrix

df = find_open_issues()
table = create_priority_label_matrix(df)
# Out:
# /Users/seanmcowen/Dropbox/BlockScience/MSML/src/math_spec_mapping/Convenience/github.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Labels"]
# /Users/seanmcowen/Dropbox/BlockScience/MSML/src/math_spec_mapping/Convenience/github.py:71: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   table = table.applymap(

# %%
from IPython.display import display_markdown, Markdown

# %%
display_markdown(Markdown(table.to_markdown()))
# Out:
# |                 | High Priority                                                                                                                                                                  | Medium Priority                                                                                                                                                                        | Low Priority                                                                                                                                                              |
# |:----------------|:-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:--------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | Bug             | [Re-running obsidian notebook can update wirings without actual changes](https://github.com/BlockScience/MSML/issues/585)                                                      | [Fix Julia Type Mappings Not Loading](https://github.com/BlockScience/MSML/issues/585)                                                                                                 |                                                                                                                                                                           |
# |                 | [There is not checking being done to make sure the type of stateful metrics actually is implemented](https://github.com/BlockScience/MSML/issues/585)                          |                                                                                                                                                                                        |                                                                                                                                                                           |
# |                 | [Boundary Actions Metaprogramming needs to change dashes to underscores](https://github.com/BlockScience/MSML/issues/585)                                                      |                                                                                                                                                                                        |                                                                                                                                                                           |
# |                 | [No Implementation Flag does not work if one of the implementations is filled in](https://github.com/BlockScience/MSML/issues/585)                                             |                                                                                                                                                                                        |                                                                                                                                                                           |
# |                 | [Repeated Called By bug](https://github.com/BlockScience/MSML/issues/585)                                                                                                      |                                                                                                                                                                                        |                                                                                                                                                                           |
# |                 | [Bug: MSML does not catch missing spaces if it is referenced in codomain](https://github.com/BlockScience/MSML/issues/585)                                                     |                                                                                                                                                                                        |                                                                                                                                                                           |
# | Communications  | [Issue Inventory Creator by Project Milestone Creator](https://github.com/BlockScience/MSML/issues/585)                                                                        | [Add README sentences on MSML as showing the back-end to non-devs](https://github.com/BlockScience/MSML/issues/585)                                                                    | [Add sub-tags to issues](https://github.com/BlockScience/MSML/issues/585)                                                                                                 |
# |                 | [Issue Inventory Creator Convenience Function](https://github.com/BlockScience/MSML/issues/585)                                                                                | [Stateful metric v metric comparison](https://github.com/BlockScience/MSML/issues/585)                                                                                                 | [Add Gov Pod presentation + walk through to presentation links](https://github.com/BlockScience/MSML/issues/585)                                                          |
# |                 | [V0.4 Update Note](https://github.com/BlockScience/MSML/issues/585)                                                                                                            | [Create documentation on the creation of research notes](https://github.com/BlockScience/MSML/issues/585)                                                                              | [Consider creating an MSML organization to host all of the canonical examples and extra stuff](https://github.com/BlockScience/MSML/issues/585)                           |
# |                 | [Make MSML option brochure of work](https://github.com/BlockScience/MSML/issues/585)                                                                                           | [Add details of integration testing applications of MSML](https://github.com/BlockScience/MSML/issues/585)                                                                             | [General-Purpose Modeling Research Note](https://github.com/BlockScience/MSML/issues/585)                                                                                 |
# |                 | [Report Creation Plan](https://github.com/BlockScience/MSML/issues/585)                                                                                                        |                                                                                                                                                                                        | [Pre-Spec Research Note](https://github.com/BlockScience/MSML/issues/585)                                                                                                 |
# |                 | [Full Issue Inventory](https://github.com/BlockScience/MSML/issues/585)                                                                                                        |                                                                                                                                                                                        | [Risk Research Note](https://github.com/BlockScience/MSML/issues/585)                                                                                                     |
# |                 | [V0.5 Project Plan](https://github.com/BlockScience/MSML/issues/585)                                                                                                           |                                                                                                                                                                                        | [Create a comparison study/sheet for displaying what is different about MSML versus incumbents](https://github.com/BlockScience/MSML/issues/585)                          |
# |                 | [Create a V0.4 major release plan](https://github.com/BlockScience/MSML/issues/585)                                                                                            |                                                                                                                                                                                        | [Add CONTRIBUTING.md](https://github.com/BlockScience/MSML/issues/585)                                                                                                    |
# |                 | [Rosetta stone research note](https://github.com/BlockScience/MSML/issues/585)                                                                                                 |                                                                                                                                                                                        |                                                                                                                                                                           |
# | DevOps          | [Can I add CI/CD that automatically makes it so the json schema docs get populated?](https://github.com/BlockScience/MSML/issues/585)                                          | [MSML to Git Issues for cadCAD Functionality](https://github.com/BlockScience/MSML/issues/585)                                                                                         | [Create .github file for CI](https://github.com/BlockScience/MSML/issues/585)                                                                                             |
# |                 |                                                                                                                                                                                | [Create a github release and/or automation](https://github.com/BlockScience/MSML/issues/585)                                                                                           |                                                                                                                                                                           |
# |                 |                                                                                                                                                                                | [Create Testing/Guardrails around the package requirements](https://github.com/BlockScience/MSML/issues/585)                                                                           |                                                                                                                                                                           |
# | Discussions     | [Consider moving all the loading logic into the individual classes as part of their init functions](https://github.com/BlockScience/MSML/issues/585)                           | [Should there be test components allowed?](https://github.com/BlockScience/MSML/issues/585)                                                                                            | [Idea: allow domain/codomain matching to be relaxed for earlier creation stuff as an optional mode](https://github.com/BlockScience/MSML/issues/585)                      |
# |                 | [Consider changing domain to mathematical domain for the symbol/domain type components](https://github.com/BlockScience/MSML/issues/585)                                       | [Can an event queue be used in place of a loop?](https://github.com/BlockScience/MSML/issues/585)                                                                                      | [Idea: For types, have an optional argument that can specify what values are allowed for things like an ENUM](https://github.com/BlockScience/MSML/issues/585)            |
# |                 | [Should the policy parameters used be based on policy options, policy only, or both?](https://github.com/BlockScience/MSML/issues/585)                                         | [Consider using obsidian as input GUI](https://github.com/BlockScience/MSML/issues/585)                                                                                                | [Consider adding a way to have types that are just List[Type A]](https://github.com/BlockScience/MSML/issues/585)                                                         |
# |                 |                                                                                                                                                                                | [Functional Parameterization compatibility mapping](https://github.com/BlockScience/MSML/issues/585)                                                                                   | [Think about codifying something like $i \in I$](https://github.com/BlockScience/MSML/issues/585)                                                                         |
# |                 |                                                                                                                                                                                | [Stock and Flow generator](https://github.com/BlockScience/MSML/issues/585)                                                                                                            | [Mechanism codomain representation research](https://github.com/BlockScience/MSML/issues/585)                                                                             |
# |                 |                                                                                                                                                                                | [Stateful metric v metric comparison](https://github.com/BlockScience/MSML/issues/585)                                                                                                 | [Should metrics have metric options?](https://github.com/BlockScience/MSML/issues/585)                                                                                    |
# |                 |                                                                                                                                                                                | [Github Pages for user documentation](https://github.com/BlockScience/MSML/issues/585)                                                                                                 | [Consider switching notes to description for entities and others](https://github.com/BlockScience/MSML/issues/585)                                                        |
# |                 |                                                                                                                                                                                | [Metric Logger Implementation](https://github.com/BlockScience/MSML/issues/585)                                                                                                        | [Consider exogenous processes and how to represent](https://github.com/BlockScience/MSML/issues/585)                                                                      |
# |                 |                                                                                                                                                                                | [Consider the idea of modifiable parameters](https://github.com/BlockScience/MSML/issues/585)                                                                                          | [Sensor](https://github.com/BlockScience/MSML/issues/585)                                                                                                                 |
# |                 |                                                                                                                                                                                | [Idea: Remote State](https://github.com/BlockScience/MSML/issues/585)                                                                                                                  | [Should control actions have the ability to say what kinds of state effects the thing happening](https://github.com/BlockScience/MSML/issues/585)                         |
# |                 |                                                                                                                                                                                |                                                                                                                                                                                        | [Discuss if constraints should be strings, actual blocks, or a combination](https://github.com/BlockScience/MSML/issues/585)                                              |
# | Documentation   | [Update MSML Canonical Example Comparison Table](https://github.com/BlockScience/MSML/issues/585)                                                                              | [Improve the semantics of pre and post processing functions](https://github.com/BlockScience/MSML/issues/585)                                                                          | [Add documentation to describe the different types of reports](https://github.com/BlockScience/MSML/issues/585)                                                           |
# |                 | [FAQ Section](https://github.com/BlockScience/MSML/issues/585)                                                                                                                 | [Add a json schema for implementations](https://github.com/BlockScience/MSML/issues/585)                                                                                               |                                                                                                                                                                           |
# |                 | [Finish JSON Spec documentation](https://github.com/BlockScience/MSML/issues/585)                                                                                              | [Stateful metric v metric comparison](https://github.com/BlockScience/MSML/issues/585)                                                                                                 |                                                                                                                                                                           |
# |                 | [Add a Getting Started Guide](https://github.com/BlockScience/MSML/issues/585)                                                                                                 | [Github Pages for user documentation](https://github.com/BlockScience/MSML/issues/585)                                                                                                 |                                                                                                                                                                           |
# |                 |                                                                                                                                                                                | [Create gameplan for docstrings / documentation](https://github.com/BlockScience/MSML/issues/585)                                                                                      |                                                                                                                                                                           |
# | Engine          | [Add the code linking and source code stuff for metrics and stateful metrics](https://github.com/BlockScience/MSML/issues/585)                                                 | [Should there be a way to have parameters + parameters used from metrics/stateful metrics for blocks?](https://github.com/BlockScience/MSML/issues/585)                                | [Add an assertion that implementations is not holding any extra keys](https://github.com/BlockScience/MSML/issues/585)                                                    |
# |                 | [Add links to the spec definition code in Obsidian output](https://github.com/BlockScience/MSML/issues/585)                                                                    | [Add performance monitoring timer](https://github.com/BlockScience/MSML/issues/585)                                                                                                    | [Idea: allow domain/codomain matching to be relaxed for earlier creation stuff as an optional mode](https://github.com/BlockScience/MSML/issues/585)                      |
# |                 | [Add something for displaying source code for wiring](https://github.com/BlockScience/MSML/issues/585)                                                                         | [Block Execution Cache](https://github.com/BlockScience/MSML/issues/585)                                                                                                               | [Change the functional parameter type from strings to a literal of the actual options](https://github.com/BlockScience/MSML/issues/585)                                   |
# |                 | [Wiring Variable Updates](https://github.com/BlockScience/MSML/issues/585)                                                                                                     | [Local parameterizations](https://github.com/BlockScience/MSML/issues/585)                                                                                                             | [Add a way to reverse read changes to Obsidian files into the spec](https://github.com/BlockScience/MSML/issues/585)                                                      |
# |                 | [Allow outputs of spaces in metrics in addition to types](https://github.com/BlockScience/MSML/issues/585)                                                                     | [Idea: Streaming Data Simulation Data](https://github.com/BlockScience/MSML/issues/585)                                                                                                | [Consider switching notes to description for entities and others](https://github.com/BlockScience/MSML/issues/585)                                                        |
# |                 | [Add checking for local state](https://github.com/BlockScience/MSML/issues/585)                                                                                                | [Idea: Add in methods that entities have similar to class definitions](https://github.com/BlockScience/MSML/issues/585)                                                                | [Create a crawler for state variables](https://github.com/BlockScience/MSML/issues/585)                                                                                   |
# |                 | [For MSI, make it possible to have the python types mapped out automatically](https://github.com/BlockScience/MSML/issues/585)                                                 | [Consider domain duplicator block](https://github.com/BlockScience/MSML/issues/585)                                                                                                    |                                                                                                                                                                           |
# |                 | [Update Remove Starter Repo Functionality](https://github.com/BlockScience/MSML/issues/585)                                                                                    | [Consider creating a pass through auto block](https://github.com/BlockScience/MSML/issues/585)                                                                                         |                                                                                                                                                                           |
# |                 | [Add __repr__ for types](https://github.com/BlockScience/MSML/issues/585)                                                                                                      | [Add a json schema for implementations](https://github.com/BlockScience/MSML/issues/585)                                                                                               |                                                                                                                                                                           |
# |                 | [Add __repr__ for components](https://github.com/BlockScience/MSML/issues/585)                                                                                                 | [Parameter Tag Ontology Library / Presets](https://github.com/BlockScience/MSML/issues/585)                                                                                            |                                                                                                                                                                           |
# |                 | [Inline wiring creation](https://github.com/BlockScience/MSML/issues/585)                                                                                                      | [Local Parameter Tag Ontologies](https://github.com/BlockScience/MSML/issues/585)                                                                                                      |                                                                                                                                                                           |
# |                 | [Add in only parameters needed dictionary option](https://github.com/BlockScience/MSML/issues/585)                                                                             | [Add ability to have no tags on parameters](https://github.com/BlockScience/MSML/issues/585)                                                                                           |                                                                                                                                                                           |
# |                 | [Make a better assertion when a boundary option is missing](https://github.com/BlockScience/MSML/issues/585)                                                                   | [Idea: Empty block for scaffolding](https://github.com/BlockScience/MSML/issues/585)                                                                                                   |                                                                                                                                                                           |
# |                 | [Idea: Native Debugging Mode](https://github.com/BlockScience/MSML/issues/585)                                                                                                 | [Change lines data["codomain"] = tuple(ms["Spaces"][x] for x in data["codomain"]) to have assertions to check spaces exist](https://github.com/BlockScience/MSML/issues/585)           |                                                                                                                                                                           |
# |                 | [Add a checker to see if all types defined are actually used](https://github.com/BlockScience/MSML/issues/585)                                                                 | [Switch policy/boundary/control action options to all be strings instead of python objects that then have JSON](https://github.com/BlockScience/MSML/issues/585)                       |                                                                                                                                                                           |
# |                 | [Add a feature that allows for null spaces to get passed in a wiring and indicate to terminate](https://github.com/BlockScience/MSML/issues/585)                               | [Consider the idea of modifiable parameters](https://github.com/BlockScience/MSML/issues/585)                                                                                          |                                                                                                                                                                           |
# |                 | [Add entities to implementation global state (after issue 153)](https://github.com/BlockScience/MSML/issues/585)                                                               | [Add tracking of parent wirings](https://github.com/BlockScience/MSML/issues/585)                                                                                                      |                                                                                                                                                                           |
# |                 | [Consider moving all the loading logic into the individual classes as part of their init functions](https://github.com/BlockScience/MSML/issues/585)                           | [Figure out fix for the issue of using a dictionary type and having it reference not yet made types](https://github.com/BlockScience/MSML/issues/585)                                  |                                                                                                                                                                           |
# |                 | [Work on making it so blocks can be more general, similar to how parameter tagging should be flexible](https://github.com/BlockScience/MSML/issues/585)                        | [Define out metadata better in the JSON](https://github.com/BlockScience/MSML/issues/585)                                                                                              |                                                                                                                                                                           |
# |                 | [Entity Implementations](https://github.com/BlockScience/MSML/issues/585)                                                                                                      | [Add a way to reference another piece of MSML with double brackets](https://github.com/BlockScience/MSML/issues/585)                                                                   |                                                                                                                                                                           |
# |                 | [Add descriptions to spaces as an attribute](https://github.com/BlockScience/MSML/issues/585)                                                                                  | [Add Codomain Mapping Special Block](https://github.com/BlockScience/MSML/issues/585)                                                                                                  |                                                                                                                                                                           |
# |                 | [Add domain and codomain checking for the executable blocks](https://github.com/BlockScience/MSML/issues/585)                                                                  | [Add Optional Flag for wiring](https://github.com/BlockScience/MSML/issues/585)                                                                                                        |                                                                                                                                                                           |
# |                 | [Add a check that the functional parameter given is indeed one of the valid control/boundary action options](https://github.com/BlockScience/MSML/issues/585)                  | [Style params dictionary](https://github.com/BlockScience/MSML/issues/585)                                                                                                             |                                                                                                                                                                           |
# |                 | [Metrics as blocks](https://github.com/BlockScience/MSML/issues/585)                                                                                                           |                                                                                                                                                                                        |                                                                                                                                                                           |
# |                 | [Add Looping Behavior for stack block implementation](https://github.com/BlockScience/MSML/issues/585)                                                                         |                                                                                                                                                                                        |                                                                                                                                                                           |
# |                 | [Figure out how to represent in the spec StatefulMetricVar.variables_used](https://github.com/BlockScience/MSML/issues/585)                                                    |                                                                                                                                                                                        |                                                                                                                                                                           |
# |                 | [Consider Adding a further base class of wiring that takes care of wiring specific stuff](https://github.com/BlockScience/MSML/issues/585)                                     |                                                                                                                                                                                        |                                                                                                                                                                           |
# |                 | [Ensure metadata is on the JSON schema as an optional type for all relevant components](https://github.com/BlockScience/MSML/issues/585)                                       |                                                                                                                                                                                        |                                                                                                                                                                           |
# |                 | [Create a JSON spec or similar for the output MSML object like is done for the input JSON](https://github.com/BlockScience/MSML/issues/585)                                    |                                                                                                                                                                                        |                                                                                                                                                                           |
# |                 | [Update the schema for mechanism updates](https://github.com/BlockScience/MSML/issues/585)                                                                                     |                                                                                                                                                                                        |                                                                                                                                                                           |
# |                 | [Add something that allows global state to reference local states as variables such as doing List[LocalState]](https://github.com/BlockScience/MSML/issues/585)                |                                                                                                                                                                                        |                                                                                                                                                                           |
# |                 | [Improve Split Block](https://github.com/BlockScience/MSML/issues/585)                                                                                                         |                                                                                                                                                                                        |                                                                                                                                                                           |
# |                 | [Add Ability to have primitive blocks](https://github.com/BlockScience/MSML/issues/585)                                                                                        |                                                                                                                                                                                        |                                                                                                                                                                           |
# |                 | [Add a function to easily query unused components](https://github.com/BlockScience/MSML/issues/585)                                                                            |                                                                                                                                                                                        |                                                                                                                                                                           |
# |                 | [Add multi-line support](https://github.com/BlockScience/MSML/issues/585)                                                                                                      |                                                                                                                                                                                        |                                                                                                                                                                           |
# | Examples        | [Update canonical examples to use the same starter repo structure](https://github.com/BlockScience/MSML/issues/585)                                                            | [Add Removing of Implementations to remove dummy repo stuff](https://github.com/BlockScience/MSML/issues/585)                                                                          | [Consider a MAIDs or killer tree canonical example](https://github.com/BlockScience/MSML/issues/585)                                                                      |
# |                 | [Retirement Planning Canonical Example V2](https://github.com/BlockScience/MSML/issues/585)                                                                                    | [Retirement Canonical Example Obsidian Pre-spec](https://github.com/BlockScience/MSML/issues/585)                                                                                      | [Pendulum Example Math Spec](https://github.com/BlockScience/MSML/issues/585)                                                                                             |
# |                 | [Create a canonical example with the ADAM algorithm](https://github.com/BlockScience/MSML/issues/585)                                                                          | [Add the allocation percentage stateful metric used for the portfolio_allocation_boundary_action in the retirement canonical example](https://github.com/BlockScience/MSML/issues/585) |                                                                                                                                                                           |
# |                 |                                                                                                                                                                                | [Consider creating a template library type of canonical example](https://github.com/BlockScience/MSML/issues/585)                                                                      |                                                                                                                                                                           |
# |                 |                                                                                                                                                                                | [Coffee Shop Canonical Example](https://github.com/BlockScience/MSML/issues/585)                                                                                                       |                                                                                                                                                                           |
# | Improvements    | [Make a better assertion when a boundary option is missing](https://github.com/BlockScience/MSML/issues/585)                                                                   | [Idea: Streaming Data Simulation Data](https://github.com/BlockScience/MSML/issues/585)                                                                                                | [Consider adding a way to have types that are just List[Type A]](https://github.com/BlockScience/MSML/issues/585)                                                         |
# |                 |                                                                                                                                                                                | [Change lines data["codomain"] = tuple(ms["Spaces"][x] for x in data["codomain"]) to have assertions to check spaces exist](https://github.com/BlockScience/MSML/issues/585)           | [Add ability to de-emphasize certain wirings by marking them with a flag that puts their reports into an "extra" wiring](https://github.com/BlockScience/MSML/issues/585) |
# |                 |                                                                                                                                                                                | [Consider relationship mapping](https://github.com/BlockScience/MSML/issues/585)                                                                                                       | [Think about codifying something like $i \in I$](https://github.com/BlockScience/MSML/issues/585)                                                                         |
# |                 |                                                                                                                                                                                | [Idea: Remote State](https://github.com/BlockScience/MSML/issues/585)                                                                                                                  | [Consider Public vs. Private Variables](https://github.com/BlockScience/MSML/issues/585)                                                                                  |
# |                 |                                                                                                                                                                                |                                                                                                                                                                                        | [Re-organize Library Structure](https://github.com/BlockScience/MSML/issues/585)                                                                                          |
# | Metaprogramming | [Boundary Actions Metaprogramming needs to change dashes to underscores](https://github.com/BlockScience/MSML/issues/585)                                                      | [Implementation Scaffolding Function](https://github.com/BlockScience/MSML/issues/585)                                                                                                 |                                                                                                                                                                           |
# |                 | [Metaprogramming is creating overwriting issues with git like reports was prior](https://github.com/BlockScience/MSML/issues/585)                                              | [Fix Julia Type Mappings Not Loading](https://github.com/BlockScience/MSML/issues/585)                                                                                                 |                                                                                                                                                                           |
# |                 | [Scaffolding tool that takes a given policy or mechanism and scaffolds what it should look like in terms of the spaces, etc.](https://github.com/BlockScience/MSML/issues/585) | [Add control action options with functional parameter control flow logic (metaprogramming)](https://github.com/BlockScience/MSML/issues/585)                                           |                                                                                                                                                                           |
# |                 | [Python Metaprogramming Metrics](https://github.com/BlockScience/MSML/issues/585)                                                                                              | [Add automatic docstring creator to boundary action metaprogramming](https://github.com/BlockScience/MSML/issues/585)                                                                  |                                                                                                                                                                           |
# |                 | [Python Metaprogramming Mechanisms](https://github.com/BlockScience/MSML/issues/585)                                                                                           | [Add version of state metaprogramming similar to pocket which allows for sweeps](https://github.com/BlockScience/MSML/issues/585)                                                      |                                                                                                                                                                           |
# ...
# | Reporting       | [Re-running obsidian notebook can update wirings without actual changes](https://github.com/BlockScience/MSML/issues/585)                                                      | [Obsidian Canvas Creator for Wirings](https://github.com/BlockScience/MSML/issues/585)                                                                                                 | [Add obsidian plugins to starter repos and have a function that also can populate them](https://github.com/BlockScience/MSML/issues/585)                                  |
# |                 | [Add a link back from state variables to the state in obsidian reporting](https://github.com/BlockScience/MSML/issues/585)                                                     | [Add Metrics and Stateful Metrics used to Mermaid Charts](https://github.com/BlockScience/MSML/issues/585)                                                                             | [Add ability to de-emphasize certain wirings by marking them with a flag that puts their reports into an "extra" wiring](https://github.com/BlockScience/MSML/issues/585) |
# |                 | [Add the code linking and source code stuff for metrics and stateful metrics](https://github.com/BlockScience/MSML/issues/585)                                                 | [Add parameters used to boundary action markdown](https://github.com/BlockScience/MSML/issues/585)                                                                                     | [Figure out how to force CSS snippets used](https://github.com/BlockScience/MSML/issues/585)                                                                              |
# |                 | [Add links to the spec definition code in Obsidian output](https://github.com/BlockScience/MSML/issues/585)                                                                    | [Stock and Flow generator](https://github.com/BlockScience/MSML/issues/585)                                                                                                            | [Idea: Top level tag for wirings](https://github.com/BlockScience/MSML/issues/585)                                                                                        |
# |                 | [Add specific line location for source code links](https://github.com/BlockScience/MSML/issues/585)                                                                            | [Idea: Auto-displays](https://github.com/BlockScience/MSML/issues/585)                                                                                                                 | [Add images assets functionality](https://github.com/BlockScience/MSML/issues/585)                                                                                        |
# |                 | [Add obsidian linking for spaces in mermaid graphic](https://github.com/BlockScience/MSML/issues/585)                                                                          | [Convert action chain report to markdown](https://github.com/BlockScience/MSML/issues/585)                                                                                             | [Mermaid graph assets functionality](https://github.com/BlockScience/MSML/issues/585)                                                                                     |
# |                 | [Add something for displaying source code for wiring](https://github.com/BlockScience/MSML/issues/585)                                                                         | [Convert entity report to markdown](https://github.com/BlockScience/MSML/issues/585)                                                                                                   | [Style Dictionary options](https://github.com/BlockScience/MSML/issues/585)                                                                                               |
# |                 | [For state variables obsidian add in mechanisms that effect it](https://github.com/BlockScience/MSML/issues/585)                                                               | [Make write basic report markdown](https://github.com/BlockScience/MSML/issues/585)                                                                                                    | [Consider a format dictionary for MSML that allows you to override certain formatting options](https://github.com/BlockScience/MSML/issues/585)                           |
# |                 | [Update state updates wiring diagram to make it super clear that state variables are not a wiring](https://github.com/BlockScience/MSML/issues/585)                            | [Atomize Writing Functions](https://github.com/BlockScience/MSML/issues/585)                                                                                                           | [Add metric linkages to the reporting for components](https://github.com/BlockScience/MSML/issues/585)                                                                    |
# |                 | [For policies/mechanisms/etc add in a section for markdown reporting that says wirings that it is involved in](https://github.com/BlockScience/MSML/issues/585)                | [Add Policy Report](https://github.com/BlockScience/MSML/issues/585)                                                                                                                   | [Metric report](https://github.com/BlockScience/MSML/issues/585)                                                                                                          |
# |                 | [Add in state variables linking for the mechanism markdown report](https://github.com/BlockScience/MSML/issues/585)                                                            | [Add parameters impacting to policy, behaviors, etc. in report write out](https://github.com/BlockScience/MSML/issues/585)                                                             | [Exclude Dictionary Feature](https://github.com/BlockScience/MSML/issues/585)                                                                                             |
# |                 | [Switch legacy reporting to be using mermaid + markdown](https://github.com/BlockScience/MSML/issues/585)                                                                      | [Make a type of report that is a parameter report](https://github.com/BlockScience/MSML/issues/585)                                                                                    | [Add Parameters to Graph Option](https://github.com/BlockScience/MSML/issues/585)                                                                                         |
# |                 | [Add Table comparing policy options, boundary options, etc](https://github.com/BlockScience/MSML/issues/585)                                                                   | [Replicate Something like write_full_state_section from the alpha version](https://github.com/BlockScience/MSML/issues/585)                                                            |                                                                                                                                                                           |
# | Research        | [Investigate MathJax or similar for Latex parsing](https://github.com/BlockScience/MSML/issues/585)                                                                            | [Get inspiration for graph renderings from matlab](https://github.com/BlockScience/MSML/issues/585)                                                                                    | [Meet on Blocks of Docs to determine overlaps](https://github.com/BlockScience/MSML/issues/585)                                                                           |
# |                 | [Explore simulink and any lessons that can be taken from it](https://github.com/BlockScience/MSML/issues/585)                                                                  | [Can an event queue be used in place of a loop?](https://github.com/BlockScience/MSML/issues/585)                                                                                      | [Research Modelica](https://github.com/BlockScience/MSML/issues/585)                                                                                                      |
# |                 |                                                                                                                                                                                | [Check out state space notebook](https://github.com/BlockScience/MSML/issues/585)                                                                                                      | [Research Modelio](https://github.com/BlockScience/MSML/issues/585)                                                                                                       |
# |                 |                                                                                                                                                                                | [Stock and Flow generator](https://github.com/BlockScience/MSML/issues/585)                                                                                                            | [Mechanism codomain representation research](https://github.com/BlockScience/MSML/issues/585)                                                                             |
# |                 |                                                                                                                                                                                | [Explore IBM MBSE article for ideas on how to improve MSML](https://github.com/BlockScience/MSML/issues/585)                                                                           | [Watch and integrate Applied Dynamical Systems Volume 1](https://github.com/BlockScience/MSML/issues/585)                                                                 |
# |                 |                                                                                                                                                                                | [Compare with SystemsComposer](https://github.com/BlockScience/MSML/issues/585)                                                                                                        | [Review The Benefits of Functional Architectures and see if anything new could be added](https://github.com/BlockScience/MSML/issues/585)                                 |
# |                 |                                                                                                                                                                                | [Compare with SysML](https://github.com/BlockScience/MSML/issues/585)                                                                                                                  | [Figure out impact of python 3.12 typing](https://github.com/BlockScience/MSML/issues/585)                                                                                |
# |                 |                                                                                                                                                                                | [Explore connections with canvases](https://github.com/BlockScience/MSML/issues/585)                                                                                                   | [Consider Using Feature Folder Structure](https://github.com/BlockScience/MSML/issues/585)                                                                                |
# |                 |                                                                                                                                                                                | [Explore DRAKON for inspiration on representation of processes](https://github.com/BlockScience/MSML/issues/585)                                                                       | [Explore the use of SQLAlchemy](https://github.com/BlockScience/MSML/issues/585)                                                                                          |
# | Simulation      | [For MSI, make it possible to have the python types mapped out automatically](https://github.com/BlockScience/MSML/issues/585)                                                 | [MSML to Git Issues for cadCAD Functionality](https://github.com/BlockScience/MSML/issues/585)                                                                                         |                                                                                                                                                                           |
# |                 | [Simulations as Blocks](https://github.com/BlockScience/MSML/issues/585)                                                                                                       | [JSON Spec for Experiment + Loading Functionality and Validation of It](https://github.com/BlockScience/MSML/issues/585)                                                               |                                                                                                                                                                           |
# |                 | [Add mapping function that maps parameter modification to metadata columns](https://github.com/BlockScience/MSML/issues/585)                                                   |                                                                                                                                                                                        |                                                                                                                                                                           |
# |                 | [Create "Experiment Groups" that let you do things like cartesian sweeps or something to create a whole bunch of experiments](https://github.com/BlockScience/MSML/issues/585) |                                                                                                                                                                                        |                                                                                                                                                                           |
# | Testing         |                                                                                                                                                                                | [Begin Building Tests](https://github.com/BlockScience/MSML/issues/585)                                                                                                                |                                                                                                                                                                           |
# | UI              |                                                                                                                                                                                | [Consider using obsidian as input GUI](https://github.com/BlockScience/MSML/issues/585)                                                                                                |                                                                                                                                                                           |

# %%
table.to_markdown()
# Out:
# '|                 | High Priority                                                                                                                                                                  | Medium Priority                                                                                                                                                                        | Low Priority                                                                                                                                                              |\n|:----------------|:-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:--------------------------------------------------------------------------------------------------------------------------------------------------------------------------|\n| Bug             | [Re-running obsidian notebook can update wirings without actual changes](https://github.com/BlockScience/MSML/issues/585)                                                      | [Fix Julia Type Mappings Not Loading](https://github.com/BlockScience/MSML/issues/585)                                                                                                 |                                                                                                                                                                           |\n|                 | [There is not checking being done to make sure the type of stateful metrics actually is implemented](https://github.com/BlockScience/MSML/issues/585)                          |                                                                                                                                                                                        |                                                                                                                                                                           |\n|                 | [Boundary Actions Metaprogramming needs to change dashes to underscores](https://github.com/BlockScience/MSML/issues/585)                                                      |                                                                                                                                                                                        |                                                                                                                                                                           |\n|                 | [No Implementation Flag does not work if one of the implementations is filled in](https://github.com/BlockScience/MSML/issues/585)                                             |                                                                                                                                                                                        |                                                                                                                                                                           |\n|                 | [Repeated Called By bug](https://github.com/BlockScience/MSML/issues/585)                                                                                                      |                                                                                                                                                                                        |                                                                                                                                                                           |\n|                 | [Bug: MSML does not catch missing spaces if it is referenced in codomain](https://github.com/B ...

# %%
import pandas as pd
pd.DataFrame([[1, 2],
              [3, 4]]).to_markdown()
# Out:
# '|    |   0 |   1 |\n|---:|----:|----:|\n|  0 |   1 |   2 |\n|  1 |   3 |   4 |'
