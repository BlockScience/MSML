# %%
import os

os.chdir("..")
from src.math_spec_mapping import find_open_issues, create_priority_label_matrix

df = find_open_issues()
table = create_priority_label_matrix(df)
# Out:
# /Users/seanmcowen/Dropbox/BlockScience/MSML/src/math_spec_mapping/Convenience/github.py:52: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Labels"]
# /Users/seanmcowen/Dropbox/BlockScience/MSML/src/math_spec_mapping/Convenience/github.py:73: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   table = table.applymap(

# %%
df
# Out:
#                                                   Name  \
# 0                                               0.3.17
# 1    Issue Inventory Creator by Project Milestone C...
# 2                               Add sub-tags to issues
# 3         Issue Inventory Creator Convenience Function
# 4                                     V0.4 Update Note
# ..                                                 ...
# 200                         Pendulum Example Math Spec
# 201                      Explore the use of SQLAlchemy
# 202                                Add CONTRIBUTING.md
# 203                         Create .github file for CI
# 204                               Begin Building Tests
#
#                                                 Labels  \
# 0                                                   []
# 1    [Label(name="Communications"), Label(name="Hig...
# 2    [Label(name="Communications"), Label(name="Low...
# 3    [Label(name="Communications"), Label(name="Hig...
# ...

# %%
from IPython.display import display_markdown, Markdown

# %%
display_markdown(Markdown(table.to_markdown()))
# Out:
# |                 | High Priority                                                                                                                                                                | Medium Priority                                                                                                                                                                      | Low Priority                                                                                                                                                            |
# ...

# %%
table.to_markdown()
# Out:
# '|                 | High Priority                                                                                                                                                                | Medium Priority                                                                                                                                                                      | Low Priority                                                                                                                                                            |\n|:----------------|:-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:----------------------------------------------------------------------
# ...

# %%
import pandas as pd
pd.DataFrame([[1, 2],
              [3, 4]]).to_markdown()
# Out:
# '|    |   0 |   1 |\n|---:|----:|----:|\n|  0 |   1 |   2 |\n|  1 |   3 |   4 |'
